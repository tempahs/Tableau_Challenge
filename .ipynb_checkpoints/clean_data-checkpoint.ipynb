# %%
import pandas as pd
from math import sin, cos, sqrt, atan2, radians

# %%
df1 = pd.read_csv("Resources/JC-202001-citibike-tripdata.csv")
df2 = pd.read_csv("Resources/JC-202002-citibike-tripdata.csv")
df3 = pd.read_csv("Resources/JC-202003-citibike-tripdata.csv")
df4 = pd.read_csv("Resources/JC-202004-citibike-tripdata.csv")
df5 = pd.read_csv("Resources/JC-202005-citibike-tripdata.csv")
df6 = pd.read_csv("Resources/JC-202006-citibike-tripdata.csv")
df7 = pd.read_csv("Resources/JC-202007-citibike-tripdata.csv")
df8 = pd.read_csv("Resources/JC-202008-citibike-tripdata.csv")
df9 = pd.read_csv("Resources/JC-202009-citibike-tripdata.csv")
df10 = pd.read_csv("Resources/JC-202010-citibike-tripdata.csv")
df11 = pd.read_csv("Resources/JC-202011-citibike-tripdata.csv")
df12 = pd.read_csv("Resources/JC-202012-citibike-tripdata.csv")

# %%
frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12]
df = pd.concat(frames).drop_duplicates()

# %%
df.to_csv("Resources/citibike_2020.csv", index=False)

# %%
# Read in new csv
df = pd.read_csv("Resources/citibike_2020.csv")
df.head(5)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# 1               -74.043117            3269   Brunswick & 6th
# 2               -74.043117            3269   Brunswick & 6th
# 3               -74.063913            3280       Astor Place
# 4               -74.043117            3276  Marin Light Rail
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.721525             -74.046305   29444  Subscriber
# 1             40.726012             -74.050389   26305  Subscriber
# 2             40.726012             -74.050389   29268    Customer
# 3             40.719282             -74.071262   29278    Customer
# 4             40.714584             -74.042817   29276  Subscriber
#
#    birth year  gender
# 0        1984       2
# 1        1989       2
# 2        1989       1
# 3        1969       0
# 4        1983       2

# %%
# Drop rows where the trip duration is less than 90 seconds and where the start and end stations are the same
# Filter out records where users rented a bike but found that it wasn't working properly
df = df.loc[((df["tripduration"]>90) & (df["start station id"] != df["end station id"])),:]
df.head(5)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# 1               -74.043117            3269   Brunswick & 6th
# 2               -74.043117            3269   Brunswick & 6th
# 3               -74.063913            3280       Astor Place
# 4               -74.043117            3276  Marin Light Rail
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.721525             -74.046305   29444  Subscriber
# 1             40.726012             -74.050389   26305  Subscriber
# 2             40.726012             -74.050389   29268    Customer
# 3             40.719282             -74.071262   29278    Customer
# 4             40.714584             -74.042817   29276  Subscriber
#
#    birth year  gender
# 0        1984       2
# 1        1989       2
# 2        1989       1
# 3        1969       0
# 4        1983       2

# %%
# Convert trip duration column from seconds to minutes
df["tripduration"] = [trip/60 for trip in df["tripduration"]]

# Filter out trips over 24 hours long
df = df.loc[df["tripduration"] < 1440, :]

# Rename trip duration column
df.rename(columns={"tripduration":"tripduration (min)"})

df.head(5)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0      3.766667  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1      6.283333  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2      4.800000  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3      7.250000  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4      3.850000  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# 1               -74.043117            3269   Brunswick & 6th
# 2               -74.043117            3269   Brunswick & 6th
# 3               -74.063913            3280       Astor Place
# 4               -74.043117            3276  Marin Light Rail
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.721525             -74.046305   29444  Subscriber
# 1             40.726012             -74.050389   26305  Subscriber
# 2             40.726012             -74.050389   29268    Customer
# 3             40.719282             -74.071262   29278    Customer
# 4             40.714584             -74.042817   29276  Subscriber
#
#    birth year  gender
# 0        1984       2
# 1        1989       2
# 2        1989       1
# 3        1969       0
# 4        1983       2

# %%
# Rename values in gender column with strings
gender = {0:"Unknown", 1:"Male", 2:"Female"}
df.gender = [gender[item] for item in df.gender]
df.head(5)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0      3.766667  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1      6.283333  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2      4.800000  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3      7.250000  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4      3.850000  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# 1               -74.043117            3269   Brunswick & 6th
# 2               -74.043117            3269   Brunswick & 6th
# 3               -74.063913            3280       Astor Place
# 4               -74.043117            3276  Marin Light Rail
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.721525             -74.046305   29444  Subscriber
# 1             40.726012             -74.050389   26305  Subscriber
# 2             40.726012             -74.050389   29268    Customer
# 3             40.719282             -74.071262   29278    Customer
# 4             40.714584             -74.042817   29276  Subscriber
#
#    birth year   gender
# 0        1984   Female
# 1        1989   Female
# 2        1989     Male
# 3        1969  Unknown
# 4        1983   Female

# %%
# Add ride id column to uniquely identify each ride
df["rideid"] = df["start station id"].map(str) + "_" + df["end station id"].map(str)
df.head(5)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0      3.766667  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1      6.283333  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2      4.800000  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3      7.250000  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4      3.850000  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# 1               -74.043117            3269   Brunswick & 6th
# 2               -74.043117            3269   Brunswick & 6th
# 3               -74.063913            3280       Astor Place
# 4               -74.043117            3276  Marin Light Rail
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.721525             -74.046305   29444  Subscriber
# 1             40.726012             -74.050389   26305  Subscriber
# 2             40.726012             -74.050389   29268    Customer
# 3             40.719282             -74.071262   29278    Customer
# 4             40.714584             -74.042817   29276  Subscriber
#
#    birth year   gender     rideid
# 0        1984   Female  3186_3211
# 1        1989   Female  3186_3269
# 2        1989     Male  3186_3269
# 3        1969  Unknown  3195_3280
# 4        1983   Female  3186_3276

# %%
# Convert degrees to radians
lat1 = [radians(lat) for lat in df["start station latitude"]]
lon1 = [radians(lon) for lon in df["start station longitude"]]
lat2 = [radians(lat) for lat in df["end station latitude"]]
lon2 = [radians(lon) for lon in df["end station longitude"]]

# Convert lists into series
lat1 = pd.Series(lat1)
lon1 = pd.Series(lon1)
lat2 = pd.Series(lat2)
lon2 = pd.Series(lon2)

# Calculate difference between each set of latitude and longitude
dlat = lat2 - lat1
dlon = lon2 - lon1

# %%
# Approximate radius of Earth in km
R = 6373.0

# Empty list to store trip distances
distance = []

for i in range(0, len(lat1)):
    
    a = sin(dlat[i] / 2)**2 + cos(lat1[i]) * cos(lat2[i]) * sin(dlon[i] / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    # Get distance and convert km to miles
    miles = (R * c) * .6214
    
    # Append miles travel to 'distance' list
    distance.append(miles)

# %%
# Add trip distance as new column to data frame
df["tripdistance (mi)"] = distance
df.head(5)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0      3.766667  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1      6.283333  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2      4.800000  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3      7.250000  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4      3.850000  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# 1               -74.043117            3269   Brunswick & 6th
# 2               -74.043117            3269   Brunswick & 6th
# 3               -74.063913            3280       Astor Place
# 4               -74.043117            3276  Marin Light Rail
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.721525             -74.046305   29444  Subscriber
# 1             40.726012             -74.050389   26305  Subscriber
# 2             40.726012             -74.050389   29268    Customer
# 3             40.719282             -74.071262   29278    Customer
# 4             40.714584             -74.042817   29276  Subscriber
#
#    birth year   gender     rideid  tripdistance (mi)
# 0        1984   Female  3186_3211           0.214093
# 1        1989   Female  3186_3269           0.585093
# 2        1989     Male  3186_3269           0.585093
# 3        1969  Unknown  3195_3280           0.890329
# 4        1983   Female  3186_3276           0.346093

# %%
# Calculate age of riders
ages = []

for i in df["birth year"]:
    age = 2019 - i
    ages.append(age)
    
# Append new Age column
df["Age"] = ages
df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0           3.766667  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           6.283333  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           4.800000  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           7.250000  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           3.850000  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 323343     11.733333  2020-12-31 22:37:08.3630  2020-12-31 22:48:52.5220
# 323345     16.366667  2020-12-31 22:59:05.5250  2020-12-31 23:15:28.3710
# 323347     25.316667  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 323348     29.350000  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 323349     10.616667  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
#
#         start station id start station name  start station latitude  \
# 0                   3186      Grove St PATH               40.719586
# 1                   3186      Grove St PATH               40.719586
# 2                   3186      Grove St PATH               40.719586
# 3                   3195            Sip Ave               40.730897
# 4                   3186      Grove St PATH               40.719586
# ...                  ...                ...                     ...
# 323343              3194    McGinley Square               40.725340
# 323345              3677       Glenwood Ave               40.727551
# 323347              3184        Paulus Hook               40.714145
# 323348              3195            Sip Ave               40.730897
# 323349              3681           Grand St               40.715178
#
#         start station longitude  end station id  end station name  \
# 0                    -74.043117            3211        Newark Ave
# 1                    -74.043117            3269   Brunswick & 6th
# 2                    -74.043117            3269   Brunswick & 6th
# 3                    -74.063913            3280       Astor Place
# 4                    -74.043117            3276  Marin Light Rail
# ...                         ...             ...               ...
# 323343               -74.067622            3203     Hamilton Park
# 323345               -74.071061            3184       Paulus Hook
# 323347               -74.033552            3195           Sip Ave
# 323348               -74.063913            3270   Jersey & 6th St
# 323349               -74.037683            3199      Newport Pkwy
#
#         end station latitude  end station longitude  bikeid    usertype  \
# 0                  40.721525             -74.046305   29444  Subscriber
# 1                  40.726012             -74.050389   26305  Subscriber
# 2                  40.726012             -74.050389   29268    Customer
# 3                  40.719282             -74.071262   29278    Customer
# 4                  40.714584             -74.042817   29276  Subscriber
# ...                      ...                    ...     ...         ...
# 323343             40.727596             -74.044247   40858    Customer
# 323345             40.714145             -74.033552   46340    Customer
# 323347             40.730897             -74.063913   46340    Customer
# 323348             40.725289             -74.045572   40907    Customer
# 323349             40.728745             -74.032108   42250    Customer
#
#         birth year   gender     rideid  tripdistance (mi)  Age
# 0             1984   Female  3186_3211           0.214093   35
# 1             1989   Female  3186_3269           0.585093   30
# 2             1989     Male  3186_3269           0.585093   30
# 3             1969  Unknown  3195_3280           0.890329   50
# 4             1983   Female  3186_3276           0.346093   36
# ...            ...      ...        ...                ...  ...
# 323343        1969  Unknown  3194_3203           1.234264   50
# 323345        1969  Unknown  3677_3184           2.172406   50
# 323347        1969  Unknown  3184_3195           1.967220   50
# 323348        1998     Male  3195_3270           1.035927   21
# 323349        1969  Unknown  3681_3199           0.982160   50
#
# [270857 rows x 18 columns]

# %%
# Delete all rows where user age is over 90
df = df.loc[df["Age"] < 90]

# %%
# Divide users in age bins
bins = [0, 17, 25, 35, 50, 65, 90]
labels = ["0-17", "18-25", "26-35", "36-50", "51-65", "65-90"]

df["Age Group"] = pd.cut(df["Age"], bins, labels=labels)
# Out:
# C:\Users\u377048\AppData\Local\Temp/ipykernel_14032/1163028816.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age Group"] = pd.cut(df["Age"], bins, labels=labels)

# %%
# Delete column
del df["birth year"]
df.head(5)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0      3.766667  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1      6.283333  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2      4.800000  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3      7.250000  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4      3.850000  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# 1               -74.043117            3269   Brunswick & 6th
# 2               -74.043117            3269   Brunswick & 6th
# 3               -74.063913            3280       Astor Place
# 4               -74.043117            3276  Marin Light Rail
#
#    end station latitude  end station longitude  bikeid    usertype   gender  \
# 0             40.721525             -74.046305   29444  Subscriber   Female
# 1             40.726012             -74.050389   26305  Subscriber   Female
# 2             40.726012             -74.050389   29268    Customer     Male
# 3             40.719282             -74.071262   29278    Customer  Unknown
# 4             40.714584             -74.042817   29276  Subscriber   Female
#
#       rideid  tripdistance (mi)  Age Age Group
# 0  3186_3211           0.214093   35     26-35
# 1  3186_3269           0.585093   30     26-35
# 2  3186_3269           0.585093   30     26-35
# 3  3195_3280           0.890329   50     36-50
# 4  3186_3276           0.346093   36     36-50

# %%
#Rename Column tripduration
df = df.rename(columns=({'tripduration':'tripduration (min)'}))
df.head(5)
# Out:
#    tripduration (min)                 starttime                  stoptime  \
# 0            3.766667  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1            6.283333  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2            4.800000  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3            7.250000  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4            3.850000  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# 1               -74.043117            3269   Brunswick & 6th
# 2               -74.043117            3269   Brunswick & 6th
# 3               -74.063913            3280       Astor Place
# 4               -74.043117            3276  Marin Light Rail
#
#    end station latitude  end station longitude  bikeid    usertype   gender  \
# 0             40.721525             -74.046305   29444  Subscriber   Female
# 1             40.726012             -74.050389   26305  Subscriber   Female
# 2             40.726012             -74.050389   29268    Customer     Male
# 3             40.719282             -74.071262   29278    Customer  Unknown
# 4             40.714584             -74.042817   29276  Subscriber   Female
#
#       rideid  tripdistance (mi)  Age Age Group
# 0  3186_3211           0.214093   35     26-35
# 1  3186_3269           0.585093   30     26-35
# 2  3186_3269           0.585093   30     26-35
# 3  3195_3280           0.890329   50     36-50
# 4  3186_3276           0.346093   36     36-50

# %%
df.to_csv("Resources/citibike_2020_FinalData.csv", index=False)
